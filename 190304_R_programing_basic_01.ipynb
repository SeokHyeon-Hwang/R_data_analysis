# %% [markdown]
# # 190304 R programing basic 01

# %%
#print(Titanic)
print(is(Titanic))
print(is(iris$Sepal.Width))
print(class(iris$Sepal.Length))
# Out:
# [1] "table"    "oldClass"
# [1] "numeric" "vector"
# [1] "numeric"

# %%
vec <- c('1', '2', '3')
is(vec)
# Out:
# [1] "character"           "vector"              "data.frameRowLabels"
# [4] "SuperClassMethod"

# %%
mat <-matrix(c(1,2,3,4,5,6), 2,3)
mat
# Out:
#      [,1] [,2] [,3]
# [1,] 1    3    5
# [2,] 2    4    6

# %%
# install.packages()
# library()

# %%
x = c(1,2,3,4,5)
x
# Out:
# [1] 1 2 3 4 5

# %%
save(x, file='x.rdata')
rm(x)
x
# 모델 저장에 활용하자!
# Out:
# Error in save(x, file = "x.rdata"): object 'x' not found
# Traceback:
#
# 1. save(x, file = "x.rdata")
# 2. stop(sprintf(ngettext(n, "object %s not found", "objects %s not found"),
#  .     paste(sQuote(list[!ok]), collapse = ", ")), domain = NA)

# %%
load('x.rdata')
x
# Out:
# [1] 1 2 3 4 5

# %% [markdown]
# ### pryr 패키지 gc() : 갈비지 콜랙션

# %%
install.packages('pryr')
# Out:
# Installing package into 'C:/Users/ktm/Documents/R/win-library/3.5'
# (as 'lib' is unspecified)
# Warning message:
# "unable to access index for repository http://www.stats.ox.ac.uk/pub/RWin/bin/windows/contrib/3.5:
#   URL 'http://www.stats.ox.ac.uk/pub/RWin/bin/windows/contrib/3.5/PACKAGES'를 열 수 없습니다"
# package 'pryr' successfully unpacked and MD5 sums checked
#
# The downloaded binary packages are in
# 	C:\Users\ktm\AppData\Local\Temp\RtmpusWCpu\downloaded_packages

# %%
date_c = c('20170302', '20180301')
substr(date_c, 5,8)
# Out:
# [1] "0302" "0301"

# %%
plot(iris)
# Out:
# plot without title

# %% [markdown]
# ### mosaicplot : 범주형 변수의 분포 파악에 도움이 된다.

# %%
mosaicplot(iris$Species, color=True)
# Out:
# Error in mosaicplot.default(iris$Species, color = True): 객체 'True'를 찾을 수 없습니다
# Traceback:
#
# 1. mosaicplot(iris$Species, color = True)
# 2. mosaicplot.default(iris$Species, color = True)

# %% [markdown]
# ### ggplot2 패키지
# #### qplot : 간단한 함수 시각화
# #### ggplot : 시각화 함수
